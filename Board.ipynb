# %%
from hyperlpr import *
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('illegal_car.jpg')
#img2 = img[:,:,::-1] # 必须为 ::-1
plt.imshow(img)

# %%
print(HyperLPR_PlateRecogntion(img))
# Out:
# [['京FC8352', 0.975575864315033, [2669, 710, 3458, 918]]]
